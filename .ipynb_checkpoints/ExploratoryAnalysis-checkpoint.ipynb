# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
trainData = pd.read_csv("train.csv",low_memory = False)

# %%
trainData.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
trainData[["Sex","Survived"]].groupby("Sex").aggregate({"sum","count","mean"})
# Out:
#        Survived
#           count      mean  sum
# Sex
# female      314  0.742038  233
# male        577  0.188908  109

# %%
trainData[["Fare","Survived"]].groupby("Fare").aggregate({"sum"})
# Out:
#          Survived
#               sum
# Fare
# 0.0000          1
# 4.0125          0
# 5.0000          0
# 6.2375          0
# 6.4375          0
# ...           ...
# 227.5250        3
# 247.5208        1
# 262.3750        2
# 263.0000        2
# 512.3292        3
#
# [248 rows x 1 columns]

# %% [markdown]
# # Sobrevivientes por clase de boleto

# %%
trainData[["Pclass","Survived"]].groupby("Pclass").aggregate({"sum","mean","count"})
# Out:
#         Survived
#             mean  sum count
# Pclass
# 1       0.629630  136   216
# 2       0.472826   87   184
# 3       0.242363  119   491

# %%
f = plt.figure()

plt.title ('tarifa y sobrevivientes',color='black')

ax = trainData[["Pclass","Survived"]].groupby("Pclass").aggregate({"sum"}).plot(kind='bar', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='red' )


ax.set_xlabel('clase')
ax.set_ylabel('cantidad de sobrevivientes')
plt.show()

# %% [markdown]
# # Sobrevivientes por tarifa

# %%
f = plt.figure()

plt.title ('tarifa y sobrevivientes',color='black')

ax = trainData[["Fare","Survived"]].groupby("Fare").aggregate({"sum"}).plot(kind='line', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='red' )


ax.set_xlabel('tarifa')
ax.set_ylabel('cantidad de sobrevivientes')
plt.show()

# %%
mean_fare = trainData["Fare"].mean()
std_fare = trainData["Fare"].std()
trainData["fare_norm"] = (trainData["Fare"] - mean_fare)/std_fare

# %%
f = plt.figure()

plt.title ('tarifa y sobrevivientes',color='black')

ax = trainData[["fare_norm","Survived"]].groupby("fare_norm").aggregate({"sum"}).plot(kind='line', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='red' )


ax.set_xlabel('tarifa')
ax.set_ylabel('cantidad de sobrevivientes')
plt.show()

# %% [markdown]
# # Sobrevivientes por edad

# %%
f = plt.figure()

plt.title ('precio y sobrevivientes',color='black')

ax = trainData[["Age","Survived"]].groupby("Age").aggregate({"sum"}).plot(kind='bar', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='red' )


ax.set_xlabel('años')
ax.set_ylabel('cantidad de sobrevivientes')
plt.show()

# %%
mean_age = trainData["Age"].mean()
std_age = trainData["Age"].std()
trainData["age_norm"] = (trainData["Age"] - mean_age)/std_age

# %%
trainData["age_norm"]
# Out:
# 0     -0.530005
# 1      0.571430
# 2     -0.254646
# 3      0.364911
# 4      0.364911
#          ...
# 886   -0.185807
# 887   -0.736524
# 888         NaN
# 889   -0.254646
# 890    0.158392
# Name: age_norm, Length: 891, dtype: float64

# %%
f = plt.figure()

plt.title ('precio y sobrevivientes',color='black')

ax = trainData[["age_norm","Survived"]].groupby("age_norm").aggregate({"sum"}).plot(kind='bar', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='red' )


ax.set_xlabel('años')
ax.set_ylabel('cantidad de sobrevivientes')
plt.show()

# %% [markdown]
# # Cantidad de pasajeros y sobrevivientes

# %%
trainData["Survived"].count()
# Out:
# 891

# %%
trainData["Survived"].sum()
# Out:
# 342

# %%
trainData["Cabin"].value_counts()
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# E101           3
# C22 C26        3
#               ..
# B80            1
# B19            1
# C30            1
# E17            1
# D9             1
# Name: Cabin, Length: 147, dtype: int64

# %%
trainData["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
trainData[["Embarked","Survived"]].groupby("Embarked").aggregate({"sum","mean","count"})
# Out:
#           Survived
#               mean  sum count
# Embarked
# C         0.553571   93   168
# Q         0.389610   30    77
# S         0.336957  217   644

# %% [markdown]
# # Ninos salvados

# %%
trainData[trainData["Age"] < 6]["Survived"].value_counts()
# Out:
# 1    31
# 0    13
# Name: Survived, dtype: int64

# %% [markdown]
# # Tipo de tickets

# %%
trainData["Ticket"].head(272)
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 267              347083
# 268            PC 17582
# 269            PC 17760
# 270              113798
# 271                LINE
# Name: Ticket, Length: 272, dtype: object

# %%
trainData[(trainData["Ticket"].map(lambda x: x.split(" ")[1] if(len(x.split(" ")) > a 1) else x)).astype(str).str.isdigit() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 115          116         0       3
# 173          174         0       3
# 179          180         0       3
# 243          244         0       3
# 271          272         1       3
# 302          303         0       3
# 382          383         0       3
# 400          401         1       3
# 414          415         1       3
# 433          434         0       3
# 473          474         1       2
# 579          580         1       3
# 590          591         0       3
# 597          598         0       3
# 636          637         0       3
# 664          665         1       3
# 744          745         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 115                         Pekoniemi, Mr. Edvard    male  21.0      0      0
# 173                     Sivola, Mr. Antti Wilhelm    male  21.0      0      0
# 179                           Leonard, Mr. Lionel    male  36.0      0      0
# 243                 Maenpaa, Mr. Matti Alexanteri    male  22.0      0      0
# 271                  Tornquist, Mr. William Henry    male  25.0      0      0
# 302               Johnson, Mr. William Cahoone Jr    male  19.0      0      0
# 382                            Tikkanen, Mr. Juho    male  32.0      0      0
# 400                            Niskanen, Mr. Juha    male  39.0      0      0
# 414                     Sundman, Mr. Johan Julian    male  44.0      0      0
# 433                    Kallio, Mr. Nikolai Erland    male  17.0      0      0
# 473  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.0      0      0
# 579                           Jussila, Mr. Eiriik    male  32.0      0      0
# 590                          Rintamaki, Mr. Matti    male  35.0      0      0
# 597                           Johnson, Mr. Alfred    male  49.0      0      0
# 636                    Leinonen, Mr. Antti Gustaf    male  32.0      0      0
# 664                   Lindqvist, Mr. Eino William    male  20.0      1      0
# 744                            Stranden, Mr. Juho    male  31.0      0      0
#
#                 Ticket     Fare Cabin Embarked
# 115  STON/O 2. 3101294   7.9250   NaN        S
# 173  STON/O 2. 3101280   7.9250   NaN        S
# 179               LINE   0.0000   NaN        S
# 243  STON/O 2. 3101275   7.1250   NaN        S
# 271               LINE   0.0000   NaN        S
# 302               LINE   0.0000   NaN        S
# 382  STON/O 2. 3101293   7.9250   NaN        S
# 400  STON/O 2. 3101289   7.9250   NaN        S
# 414  STON/O 2. 3101269   7.9250   NaN        S
# 433  STON/O 2. 3101274   7.1250   NaN        S
# 473    SC/AH Basle 541  13.7917     D        C
# 579  STON/O 2. 3101286   7.9250   NaN        S
# 590  STON/O 2. 3101273   7.1250   NaN        S
# 597               LINE   0.0000   NaN        S
# 636  STON/O 2. 3101292   7.9250   NaN        S
# 664  STON/O 2. 3101285   7.9250   NaN        S
# 744  STON/O 2. 3101288   7.9250   NaN        S

# %%
def mapTicket(x):
    if(len(x.split(" ")) == 2):
        if( x.split(" ")[1] == "LINE"):
            return -1
        return x.split(" ")[1]
    elif(len(x.split(" ")) == 3):
        if( x.split(" ")[2] == "LINE"):
            return -1
        return x.split(" ")[2]
    elif(str(x).isdigit()):
        return x

# %%
# Out:
# -1

# %%
trainData[(trainData["Ticket"].map(lambda x: mapTicket(x))).astype(str).str.isdigit() == False]["Ticket"].map(lambda x: mapTicket(x))
# Out:
# 179   -1
# 271   -1
# 302   -1
# 597   -1
# Name: Ticket, dtype: int64

# %%
(trainData["Ticket"].astype(str).str.isdigit() == True)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Ticket, Length: 891, dtype: bool

# %%
trainData[ trainData["Ticket"].astype(str).str.isdigit() == True]["Survived"].value_counts()
# Out:
# 0    407
# 1    254
# Name: Survived, dtype: int64

# %%
ticket_survived = trainData[ trainData["Ticket"].astype(str).str.isdigit() == True][["Survived","Ticket"]]

# %%
ticket_survived["Ticket"] = ticket_survived["Ticket"].astype(int)

# %%
ticket_survived.sort_values("Ticket",ascending = True).head(700)
# Out:
#      Survived   Ticket
# 545         0      693
# 872         0      695
# 838         1     1601
# 169         0     1601
# 692         1     1601
# ..        ...      ...
# 266         0  3101295
# 164         0  3101295
# 638         0  3101295
# 528         0  3101296
# 479         1  3101298
#
# [661 rows x 2 columns]

# %%
f = plt.figure()

plt.title ('tarifa y sobrevivientes',color='black')

ax = ticket_survived[ticket_survived["Ticket"]<500000].groupby("Ticket").sum().sort_values("Ticket",ascending = True).plot(kind='line', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='red' )
ticket_survived[ticket_survived["Ticket"]<500000].groupby("Ticket").count().sort_values("Ticket",ascending = True).plot(kind='line', figsize=(50,20) ,alpha=0.75, ax=f.gca(), color='blue' )

ax.set_xlabel('tarifa')
ax.set_ylabel('cantidad de sobrevivientes')
plt.show()

# %%
trainData["Cabin"].isna().value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
trainData[trainData["Cabin"].isna()]["Survived"].value_counts()
# Out:
# 0    481
# 1    206
# Name: Survived, dtype: int64

# %%
trainData[trainData["Cabin"].isna() == False]["Survived"].value_counts() #los que tiene cabina la mayoria se salva
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-7eb9bd39bf2c> in <module>
# ----> 1 trainData[trainData["Cabin"].isna() == False and trainData["Cabin"]<500000 ]["Survived"].value_counts() #los que tiene cabina la mayoria se salva
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# # Parch

# %%
trainData[["Parch","Survived"]].groupby("Parch").aggregate({"sum","count","mean"})
# Out:
#       Survived
#          count  sum      mean
# Parch
# 0          678  233  0.343658
# 1          118   65  0.550847
# 2           80   40  0.500000
# 3            5    3  0.600000
# 4            4    0  0.000000
# 5            5    1  0.200000
# 6            1    0  0.000000

# %% [markdown]
# # SibSP

# %%
trainData[["SibSp","Survived"]].groupby("SibSp").aggregate({"sum","count","mean"})
# Out:
#       Survived
#          count  sum      mean
# SibSp
# 0          608  210  0.345395
# 1          209  112  0.535885
# 2           28   13  0.464286
# 3           16    4  0.250000
# 4           18    3  0.166667
# 5            5    0  0.000000
# 8            7    0  0.000000

# %%
trainData["Name"].head(20)
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# 16                                 Rice, Master. Eugene
# 17                         Williams, Mr. Charles Eugene
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19                              Masselmani, Mrs. Fatima
# Name: Name, dtype: object
